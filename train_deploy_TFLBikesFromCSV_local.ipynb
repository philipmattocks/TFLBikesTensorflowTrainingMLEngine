# %% [markdown]
# <h1> Structured data prediction using Cloud ML Engine </h1>
#
# This notebook illustrates:
# <ol>
# <li> Creating datasets for Machine Learning using Dataflow
# <li> Creating a model using the high-level Estimator API
# <li> Training on Cloud ML Engine
# <li> Deploying model
# <li> Predicting with model
# </ol>

# %%
# change these to try this notebook out
#BUCKET = 'tflbikeuse'
#PROJECT = 'TFLBikeUse'
#REGION = 'us-central1'
import shutil
import numpy as np
import tensorflow as tf
BUCKET = 'tflbikesbucketregional'
PROJECT = 'TFLBikeUse-philipkm'
PROJECT_ID = 'tflbikeuse-philipkm'
REGION = 'us-central1'

# %%
import os
os.environ['BUCKET'] = BUCKET
os.environ['PROJECT'] = PROJECT
os.environ['REGION'] = REGION

# %% [markdown]
# <h2> Create ML dataset using Dataflow (I didn't do this)</h2>
# <p>
# We can use Cloud Dataflow to read in the BigQuery data and write it out as CSV files.
#
# Instead of using Beam/Dataflow, I had three other options:
# <ol>
# <li> Use Cloud Dataprep to visually author a Dataflow pipeline. Cloud Dataprep also allows me to explore the data, so we could have avoided much of the handcoding of Python/Seaborn calls above as well!
# <li> Read from BigQuery directly using TensorFlow.
# <li> Use the BigQuery console (http://bigquery.cloud.google.com) to run a Query and save the result as a CSV file. For larger datasets, you may have to select the option to "allow large results" and save the result into a CSV file on Google Cloud Storage.
# </ol>
# <p>
# However, in this case, I want to do some preprocessing, modifying data so that we can simulate what is known if no ultrasound has been performed. If I didn't need preprocessing, I could have used the web console. Also, I prefer to script it out rather than run queries on the user interface, so I am using Cloud Dataflow for the preprocessing.
# <p>
# Note that I have set in_test_mode=True in the following code -- this will run the code locally on a small subset of the data -- the full results were copied into your bucket using the following code (in the previous cell):
# <pre>
# gsutil -m cp -R gs://cloud-training-demos/babyweight gs://${BUCKET}
# </pre>
# If you are running in your own project, change in_test_mode=False; after you launch this, the notebook will appear to be hung. Go to the GCP webconsole to the Dataflow section and monitor the running job. It took about <b>30 minutes</b> for me with autoscaling to 15 workers -- Qwiklabs accounts won't be able scale to that level, and so doing it on Qwiklabs would have taken 3-4 hours. Hence, the short-cut.

# %%
#PHILM: I skipped this part
import apache_beam as beam
import datetime

def to_csv(rowdict):
    # pull columns from BQ and create a line
    import hashlib
    import copy
    CSV_COLUMNS = 'weight_pounds,is_male,mother_age,plurality,gestation_weeks'.split(',')
    
    # create synthetic data where we assume that no ultrasound has been performed
    # and so we don't know sex of the baby. Let's assume that we can tell the difference
    # between single and multiple, but that the errors rates in determining exact number
    # is difficult in the absence of an ultrasound.
    no_ultrasound = copy.deepcopy(rowdict)
    w_ultrasound = copy.deepcopy(rowdict)

    no_ultrasound['is_male'] = 'Unknown'
    if rowdict['plurality'] > 1:
      no_ultrasound['plurality'] = 'Multiple(2+)'
    else:
      no_ultrasound['plurality'] = 'Single(1)'
      
    # Change the plurality column to strings
    w_ultrasound['plurality'] = ['Single(1)', 'Twins(2)', 'Triplets(3)', 'Quadruplets(4)', 'Quintuplets(5)'][rowdict['plurality']-1]
    
    # Write out two rows for each input row, one with ultrasound and one without
    for result in [no_ultrasound, w_ultrasound]:
      data = ','.join([str(result[k]) if k in result else 'None' for k in CSV_COLUMNS])
      key = hashlib.sha224(data).hexdigest()  # hash the columns to form a key
      yield str('{},{}'.format(data, key))
  
def preprocess(in_test_mode):
    job_name = 'preprocess-babyweight-features' + '-' + datetime.datetime.now().strftime('%y%m%d-%H%M%S')
    
    if in_test_mode:
        print 'Launching local job ... hang on'
        OUTPUT_DIR = './preproc'
    else:
        print 'Launching Dataflow job {} ... hang on'.format(job_name)
        OUTPUT_DIR = 'gs://{0}/babyweight/preproc/'.format(BUCKET)
    
    options = {
        'staging_location': os.path.join(OUTPUT_DIR, 'tmp', 'staging'),
        'temp_location': os.path.join(OUTPUT_DIR, 'tmp'),
        'job_name': job_name,
        'project': PROJECT,
        'teardown_policy': 'TEARDOWN_ALWAYS',
        'no_save_main_session': True
    }
    opts = beam.pipeline.PipelineOptions(flags=[], **options)
    if in_test_mode:
        RUNNER = 'DirectRunner'
    else:
        RUNNER = 'DataflowRunner'
    p = beam.Pipeline(RUNNER, options=opts)
    query = """
SELECT
  weight_pounds,
  is_male,
  mother_age,
  plurality,
  gestation_weeks,
  FARM_FINGERPRINT(CONCAT(CAST(YEAR AS STRING), CAST(month AS STRING))) AS hashmonth
FROM
  publicdata.samples.natality
WHERE year > 2000
AND weight_pounds > 0
AND mother_age > 0
AND plurality > 0
AND gestation_weeks > 0
AND month > 0
    """
  
    if in_test_mode:
        query = query + ' LIMIT 100' 
  
    for step in ['train', 'eval']:
        if step == 'train':
            selquery = 'SELECT * FROM ({}) WHERE MOD(ABS(hashmonth),4) < 3'.format(query)
        else:
            selquery = 'SELECT * FROM ({}) WHERE MOD(ABS(hashmonth),4) = 3'.format(query)

        (p 
         | '{}_read'.format(step) >> beam.io.Read(beam.io.BigQuerySource(query=selquery, use_standard_sql=True))
         | '{}_csv'.format(step) >> beam.FlatMap(to_csv)
         | '{}_out'.format(step) >> beam.io.Write(beam.io.WriteToText(os.path.join(OUTPUT_DIR, '{}.csv'.format(step))))
        )
 
    job = p.run()
  
preprocess(in_test_mode=True)
# Out:
#   File "<ipython-input-7-f68f8f1306c9>", line 37
#     print 'Launching local job ... hang on'
#                                           ^
# SyntaxError: Missing parentheses in call to 'print'

# %% [markdown]
# <img src="dataflow.png" width="500"/>

# %% [markdown]
# <H2> Check Data is Present<H2>

# %%
# %bash
#gsutil ls gs://tflbikeuse/eval*
#gsutil cat -r 0-256 gs://tflbikeuse/eval*
#gsutil ls gs://tflbikeuse/train*
#gsutil cat -r 0-256 gs://tflbikeuse/train*
gsutil cat gs://tflbikesbucketregional/train*|wc -l
# Out:
# 4758633

# %% [markdown]
# <h2> Create TensorFlow model using TensorFlow's Estimator API </h2>
# <p>
# First, write an input_fn to read the data.

# %%
CSV_COLUMNS =  'precipIntensity,temperature,badWeather,hour,dayofweek,bikesused,key,weekend'.split(',')
LABEL_COLUMN = 'bikesused'
KEY_COLUMN = 'key'
DEFAULTS = [[0.0],[15.0],["False"],[0],['Monday'],[0.5], ['nokey'],["False"]]

def read_dataset(prefix, pattern, batch_size=512):
    # use prefix to create filename
    filename = 'gs://{}/{}*'.format(BUCKET, prefix, pattern)   
    print(filename)
    if prefix == 'train':
        mode = tf.estimator.ModeKeys.TRAIN
        num_epochs = None # indefinitely
    else:
        mode = tf.estimator.ModeKeys.EVAL
        num_epochs = 1 # end-of-input after this
    
    # the actual input function passed to TensorFlow
    def _input_fn():
        # could be a path to one file or a file pattern.
        input_file_names = tf.train.match_filenames_once(filename)
        filename_queue = tf.train.string_input_producer(
            input_file_names, shuffle=True, num_epochs=num_epochs)
 
        # read CSV
        reader = tf.TextLineReader(skip_header_lines=1)
        _, value = reader.read_up_to(filename_queue, num_records=batch_size)
        if mode == tf.estimator.ModeKeys.TRAIN:
          value = tf.train.shuffle_batch([value], batch_size, capacity=10*batch_size, 
                                         min_after_dequeue=batch_size, enqueue_many=True, 
                                         allow_smaller_final_batch=False)
        value_column = tf.expand_dims(value, -1)
        columns = tf.decode_csv(value_column, record_defaults=DEFAULTS)
        features = dict(zip(CSV_COLUMNS, columns))
        features.pop(KEY_COLUMN)
        #features.pop('callTime')
        label = features.pop(LABEL_COLUMN)
        return features, label
  
    return _input_fn

# %% [markdown]
# Next, define the feature columns

# %%
def get_wide_deep():
    # define column types
    #is_male,mother_age,plurality,gestation_weeks = \
    badWeather,precipIntensity,temperature,hour,weekend,dayofweek = \
        [\
            #tf.feature_column.numeric_column('badWeather'),
            tf.feature_column.categorical_column_with_vocabulary_list('badWeather',['True','False']),
            tf.feature_column.numeric_column('precipIntensity'),
            tf.feature_column.numeric_column('temperature'),
            tf.feature_column.numeric_column('hour'),
            #tf.feature_column.numeric_column('weekend'),
            tf.feature_column.categorical_column_with_vocabulary_list('weekend',['True','False']),
            tf.feature_column.categorical_column_with_vocabulary_list('dayofweek',['Sunday', 'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'])
        ]

    # discretize
    hour_buckets = tf.feature_column.bucketized_column(hour, 
                        boundaries=np.arange(0,24,1).tolist())
    
   # precipIntensity_buckets=tf.feature_column.bucketized_column(precipIntensity, 
   #                     boundaries=np.arange(0,25,1).tolist())
   # 
   # temperature_buckets=tf.feature_column.bucketized_column(temperature, 
   #                     boundaries=np.arange(-10,30,1).tolist())
      
    # sparse columns are wide 
    #wide = [badWeather,
    #        #hour_buckets,
    #        weekend,
    #        dayofweek]
   #wide = [badWeather,
   #        hour_buckets,
   #        precipIntensity_buckets,
   #        temperature_buckets,
   #        weekend,
   #        dayofweek]
      
    # feature cross all the wide columns and embed into a lower dimension
    #Columns
    #crossed = tf.feature_column.crossed_column(wide, hash_bucket_size=20000)
    #embed = tf.feature_column.embedding_column(crossed, 4)
    badWeather_indicator = tf.feature_column.indicator_column(badWeather)
    dayofweek_indicator = tf.feature_column.indicator_column(dayofweek)
    weekend_indicator = tf.feature_column.indicator_column(weekend)
    #badWeather=tf.feature_column.indicator_column(categorical_column)
    # continuous columns are deep
    #deep = [badWeather,
    #        embed]
    #indicators = [badWeather_indicator,
                  #dayofweek_indicator,
                  #weekend_indicator]
    #        embed]
    features = [precipIntensity,temperature,hour_buckets,badWeather_indicator,dayofweek_indicator,weekend_indicator]
    return features
   #return features

# %% [markdown]
# To predict with the TensorFlow model, we also need a serving input function. We will want all the inputs from our user.

# %%
def serving_input_fn():
    feature_placeholders = {
        'hour': tf.placeholder(tf.float32, [None]),
        'dayofweek': tf.placeholder(tf.string, [None]),
        'weekend': tf.placeholder(tf.string, [None]),
        #'badWeather': tf.placeholder(tf.bool, [None])
        'badWeather': tf.placeholder(tf.string, [None]),
        'temperature': tf.placeholder(tf.float32, [None]),
        'precipIntensity': tf.placeholder(tf.float32, [None])
    }
    features = {
        key: tf.expand_dims(tensor, -1)
        for key, tensor in feature_placeholders.items()
    }
    return tf.estimator.export.ServingInputReceiver(features, feature_placeholders)

from tensorflow.contrib.learn.python.learn.utils import saved_model_export_utils

# %% [markdown]
# Finally, train!

# %%
from tensorflow.contrib.learn.python.learn.utils import saved_model_export_utils
from tensorflow.contrib.learn.python.learn import learn_runner

PATTERN = ""  # process only one of the shards, for testing purposes

def train_and_evaluate(output_dir):
    features = get_wide_deep()
    estimator = tf.estimator.DNNRegressor(
                         model_dir=output_dir,
                         #linear_feature_columns=wide,
                         #dnn_feature_columns=deep,
                         feature_columns=features,
                         #dnn_hidden_units=[64, 32])#,
                         hidden_units=[64, 32])
                         #config = run_config)
    train_spec=tf.estimator.TrainSpec(
                         input_fn=read_dataset('train', PATTERN),
                         max_steps=10000)
    exporter = tf.estimator.LatestExporter('exporter',serving_input_fn)
    eval_spec=tf.estimator.EvalSpec(
                         input_fn=read_dataset('eval', PATTERN),
                         steps=None,
                         start_delay_secs = 1, # start evaluating after N seconds
                         throttle_secs = 10,  # evaluate every N seconds
                         exporters=exporter)
    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
    
shutil.rmtree('tfl_trained_120419_1600', ignore_errors=True) # start fresh each time
train_and_evaluate('tfl_trained_120419_1600')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_log_step_count_steps': 100, '_num_ps_replicas': 0, '_evaluation_master': '', '_session_config': None, '_is_chief': True, '_train_distribute': None, '_save_checkpoints_secs': 600, '_service': None, '_model_dir': 'tfl_trained_120419_1600', '_master': '', '_task_type': 'worker', '_tf_random_seed': None, '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f0ffa6e24e0>, '_global_id_in_cluster': 0, '_num_worker_replicas': 1, '_keep_checkpoint_every_n_hours': 10000, '_task_id': 0, '_keep_checkpoint_max': 5}
# gs://tflbikesbucketregional/train*
# gs://tflbikesbucketregional/eval*
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 10 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 1, loss = 152.91278
# INFO:tensorflow:global_step/sec: 88.496
# INFO:tensorflow:step = 101, loss = 47.0146 (1.135 sec)
# INFO:tensorflow:global_step/sec: 93.8692
# INFO:tensorflow:step = 201, loss = 48.822384 (1.067 sec)
# INFO:tensorflow:global_step/sec: 89.4447
# INFO:tensorflow:step = 301, loss = 46.854416 (1.116 sec)
# INFO:tensorflow:global_step/sec: 93.6992
# INFO:tensorflow:step = 401, loss = 42.63024 (1.069 sec)
# INFO:tensorflow:global_step/sec: 93.2424
# INFO:tensorflow:step = 501, loss = 45.91461 (1.070 sec)
# INFO:tensorflow:global_step/sec: 96.8074
# INFO:tensorflow:step = 601, loss = 49.141773 (1.033 sec)
# INFO:tensorflow:global_step/sec: 93.7282
# INFO:tensorflow:step = 701, loss = 48.136562 (1.069 sec)
# INFO:tensorflow:Saving checkpoints for 782 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 49.498543.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:07:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:07:28
# INFO:tensorflow:Saving dict for global step 782: average_loss = 0.092331834, global_step = 782, loss = 47.245663
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-782
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081649'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 783, loss = 43.40387
# INFO:tensorflow:global_step/sec: 90.24
# INFO:tensorflow:step = 883, loss = 49.782887 (1.116 sec)
# INFO:tensorflow:global_step/sec: 95.2331
# INFO:tensorflow:step = 983, loss = 48.18706 (1.047 sec)
# INFO:tensorflow:global_step/sec: 91.4401
# INFO:tensorflow:step = 1083, loss = 45.286625 (1.096 sec)
# INFO:tensorflow:global_step/sec: 91.2403
# INFO:tensorflow:step = 1183, loss = 43.265415 (1.094 sec)
# INFO:tensorflow:global_step/sec: 93.5317
# INFO:tensorflow:step = 1283, loss = 40.213394 (1.072 sec)
# INFO:tensorflow:global_step/sec: 93.6045
# INFO:tensorflow:step = 1383, loss = 46.516014 (1.066 sec)
# INFO:tensorflow:global_step/sec: 95.6556
# INFO:tensorflow:step = 1483, loss = 49.13012 (1.045 sec)
# INFO:tensorflow:global_step/sec: 95.2208
# INFO:tensorflow:step = 1583, loss = 49.84816 (1.053 sec)
# INFO:tensorflow:Saving checkpoints for 1631 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 49.397903.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:07:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-1631
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:07:54
# INFO:tensorflow:Saving dict for global step 1631: average_loss = 0.09224868, global_step = 1631, loss = 47.20311
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-1631
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081674'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-1631
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1632 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 1632, loss = 46.20708
# INFO:tensorflow:global_step/sec: 87.4222
# INFO:tensorflow:step = 1732, loss = 52.642067 (1.151 sec)
# INFO:tensorflow:global_step/sec: 92.7737
# INFO:tensorflow:step = 1832, loss = 48.11212 (1.075 sec)
# INFO:tensorflow:global_step/sec: 93.7868
# INFO:tensorflow:step = 1932, loss = 46.947403 (1.067 sec)
# INFO:tensorflow:global_step/sec: 94.5665
# INFO:tensorflow:step = 2032, loss = 43.511772 (1.057 sec)
# INFO:tensorflow:global_step/sec: 90.1905
# INFO:tensorflow:step = 2132, loss = 48.000984 (1.109 sec)
# INFO:tensorflow:global_step/sec: 96.3814
# INFO:tensorflow:step = 2232, loss = 48.0306 (1.039 sec)
# INFO:tensorflow:global_step/sec: 81.542
# INFO:tensorflow:step = 2332, loss = 49.65771 (1.225 sec)
# INFO:tensorflow:global_step/sec: 92.2175
# INFO:tensorflow:step = 2432, loss = 49.38685 (1.087 sec)
# INFO:tensorflow:Saving checkpoints for 2462 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 48.802185.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:08:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-2462
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:08:15
# INFO:tensorflow:Saving dict for global step 2462: average_loss = 0.09216384, global_step = 2462, loss = 47.159695
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-2462
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081696'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-2462
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2463 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 2463, loss = 45.52843
# INFO:tensorflow:global_step/sec: 87.7112
# INFO:tensorflow:step = 2563, loss = 49.86894 (1.147 sec)
# INFO:tensorflow:global_step/sec: 94.2861
# INFO:tensorflow:step = 2663, loss = 50.911858 (1.059 sec)
# INFO:tensorflow:global_step/sec: 89.4683
# INFO:tensorflow:step = 2763, loss = 43.224186 (1.120 sec)
# INFO:tensorflow:global_step/sec: 96.4426
# INFO:tensorflow:step = 2863, loss = 45.028885 (1.035 sec)
# INFO:tensorflow:global_step/sec: 100.282
# INFO:tensorflow:step = 2963, loss = 44.94388 (0.997 sec)
# INFO:tensorflow:global_step/sec: 95.5261
# INFO:tensorflow:step = 3063, loss = 49.72032 (1.050 sec)
# INFO:tensorflow:global_step/sec: 96.8358
# INFO:tensorflow:step = 3163, loss = 51.639015 (1.030 sec)
# INFO:tensorflow:global_step/sec: 100.338
# INFO:tensorflow:step = 3263, loss = 52.051773 (0.997 sec)
# INFO:tensorflow:Saving checkpoints for 3334 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 49.601597.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:08:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-3334
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:08:37
# INFO:tensorflow:Saving dict for global step 3334: average_loss = 0.09220809, global_step = 3334, loss = 47.18234
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-3334
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081717'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-3334
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3335 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 3335, loss = 45.559807
# INFO:tensorflow:global_step/sec: 88.6368
# INFO:tensorflow:step = 3435, loss = 47.851715 (1.135 sec)
# INFO:tensorflow:global_step/sec: 100.567
# INFO:tensorflow:step = 3535, loss = 46.93686 (0.993 sec)
# INFO:tensorflow:global_step/sec: 97.5254
# INFO:tensorflow:step = 3635, loss = 41.366867 (1.025 sec)
# INFO:tensorflow:global_step/sec: 96.5191
# INFO:tensorflow:step = 3735, loss = 44.264095 (1.039 sec)
# INFO:tensorflow:global_step/sec: 93.5986
# INFO:tensorflow:step = 3835, loss = 45.71237 (1.066 sec)
# INFO:tensorflow:global_step/sec: 95.9712
# INFO:tensorflow:step = 3935, loss = 47.195473 (1.041 sec)
# INFO:tensorflow:global_step/sec: 96.1847
# INFO:tensorflow:step = 4035, loss = 49.929237 (1.043 sec)
# INFO:tensorflow:global_step/sec: 95.7751
# INFO:tensorflow:step = 4135, loss = 50.65341 (1.042 sec)
# INFO:tensorflow:Saving checkpoints for 4207 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 47.904903.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:08:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-4207
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:08:58
# INFO:tensorflow:Saving dict for global step 4207: average_loss = 0.09216377, global_step = 4207, loss = 47.159664
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-4207
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081739'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-4207
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4208 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 4208, loss = 45.05551
# INFO:tensorflow:global_step/sec: 90.4407
# INFO:tensorflow:step = 4308, loss = 49.637115 (1.112 sec)
# INFO:tensorflow:global_step/sec: 94.5152
# INFO:tensorflow:step = 4408, loss = 48.67745 (1.056 sec)
# INFO:tensorflow:global_step/sec: 92.2072
# INFO:tensorflow:step = 4508, loss = 43.48039 (1.084 sec)
# INFO:tensorflow:global_step/sec: 92.5128
# INFO:tensorflow:step = 4608, loss = 45.21682 (1.083 sec)
# INFO:tensorflow:global_step/sec: 95.0532
# INFO:tensorflow:step = 4708, loss = 46.718346 (1.050 sec)
# INFO:tensorflow:global_step/sec: 97.5266
# INFO:tensorflow:step = 4808, loss = 46.1292 (1.025 sec)
# INFO:tensorflow:global_step/sec: 97.2564
# INFO:tensorflow:step = 4908, loss = 46.282547 (1.028 sec)
# INFO:tensorflow:global_step/sec: 96.9664
# INFO:tensorflow:step = 5008, loss = 49.97905 (1.033 sec)
# INFO:tensorflow:Saving checkpoints for 5076 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 46.295937.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:09:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-5076
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:09:20
# INFO:tensorflow:Saving dict for global step 5076: average_loss = 0.09224074, global_step = 5076, loss = 47.199047
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-5076
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081760'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-5076
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5077 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 5077, loss = 42.642006
# INFO:tensorflow:global_step/sec: 92.7501
# INFO:tensorflow:step = 5177, loss = 50.757633 (1.083 sec)
# INFO:tensorflow:global_step/sec: 97.666
# INFO:tensorflow:step = 5277, loss = 49.058174 (1.026 sec)
# INFO:tensorflow:global_step/sec: 89.7427
# INFO:tensorflow:step = 5377, loss = 45.505577 (1.112 sec)
# INFO:tensorflow:global_step/sec: 98.664
# INFO:tensorflow:step = 5477, loss = 42.840153 (1.013 sec)
# INFO:tensorflow:global_step/sec: 97.4333
# INFO:tensorflow:step = 5577, loss = 48.89241 (1.029 sec)
# INFO:tensorflow:global_step/sec: 98.9328
# INFO:tensorflow:step = 5677, loss = 50.034294 (1.008 sec)
# INFO:tensorflow:global_step/sec: 98.5515
# INFO:tensorflow:step = 5777, loss = 44.081833 (1.015 sec)
# INFO:tensorflow:global_step/sec: 96.0044
# INFO:tensorflow:step = 5877, loss = 46.53383 (1.043 sec)
# INFO:tensorflow:Saving checkpoints for 5955 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 51.881706.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:09:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-5955
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:09:41
# INFO:tensorflow:Saving dict for global step 5955: average_loss = 0.0926553, global_step = 5955, loss = 47.411175
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-5955
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081781'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-5955
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5956 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 5956, loss = 47.95935
# INFO:tensorflow:global_step/sec: 90.8146
# INFO:tensorflow:step = 6056, loss = 49.710354 (1.106 sec)
# INFO:tensorflow:global_step/sec: 95.329
# INFO:tensorflow:step = 6156, loss = 48.21212 (1.051 sec)
# INFO:tensorflow:global_step/sec: 94.1065
# INFO:tensorflow:step = 6256, loss = 43.065273 (1.061 sec)
# INFO:tensorflow:global_step/sec: 95.8682
# INFO:tensorflow:step = 6356, loss = 46.769684 (1.044 sec)
# INFO:tensorflow:global_step/sec: 96.1528
# INFO:tensorflow:step = 6456, loss = 44.722137 (1.041 sec)
# INFO:tensorflow:global_step/sec: 95.5333
# INFO:tensorflow:step = 6556, loss = 47.09355 (1.045 sec)
# INFO:tensorflow:global_step/sec: 95.3662
# INFO:tensorflow:step = 6656, loss = 49.66798 (1.048 sec)
# INFO:tensorflow:global_step/sec: 95.03
# INFO:tensorflow:step = 6756, loss = 49.493828 (1.054 sec)
# INFO:tensorflow:Saving checkpoints for 6827 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 48.126785.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:09:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-6827
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:10:02
# INFO:tensorflow:Saving dict for global step 6827: average_loss = 0.09227937, global_step = 6827, loss = 47.218815
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-6827
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081803'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-6827
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6828 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 6828, loss = 46.928894
# INFO:tensorflow:global_step/sec: 86.7894
# INFO:tensorflow:step = 6928, loss = 47.82158 (1.157 sec)
# INFO:tensorflow:global_step/sec: 98.0576
# INFO:tensorflow:step = 7028, loss = 43.48398 (1.022 sec)
# INFO:tensorflow:global_step/sec: 97.2749
# INFO:tensorflow:step = 7128, loss = 39.115425 (1.027 sec)
# INFO:tensorflow:global_step/sec: 96.86
# INFO:tensorflow:step = 7228, loss = 44.468895 (1.032 sec)
# INFO:tensorflow:global_step/sec: 96.4804
# INFO:tensorflow:step = 7328, loss = 44.201653 (1.038 sec)
# INFO:tensorflow:global_step/sec: 99.1665
# INFO:tensorflow:step = 7428, loss = 48.78895 (1.007 sec)
# INFO:tensorflow:global_step/sec: 98.9177
# INFO:tensorflow:step = 7528, loss = 47.706512 (1.011 sec)
# INFO:tensorflow:global_step/sec: 99.8375
# INFO:tensorflow:step = 7628, loss = 47.882835 (1.003 sec)
# INFO:tensorflow:Saving checkpoints for 7711 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 50.158195.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:10:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-7711
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:10:24
# INFO:tensorflow:Saving dict for global step 7711: average_loss = 0.09232223, global_step = 7711, loss = 47.240746
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-7711
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081824'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-7711
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7712 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 7712, loss = 43.58886
# INFO:tensorflow:global_step/sec: 90.1854
# INFO:tensorflow:step = 7812, loss = 48.03334 (1.114 sec)
# INFO:tensorflow:global_step/sec: 95.8177
# INFO:tensorflow:step = 7912, loss = 46.93476 (1.046 sec)
# INFO:tensorflow:global_step/sec: 94.7508
# INFO:tensorflow:step = 8012, loss = 40.14379 (1.053 sec)
# INFO:tensorflow:global_step/sec: 96.5349
# INFO:tensorflow:step = 8112, loss = 45.30046 (1.038 sec)
# INFO:tensorflow:global_step/sec: 94.2857
# INFO:tensorflow:step = 8212, loss = 46.92676 (1.061 sec)
# INFO:tensorflow:global_step/sec: 98.5955
# INFO:tensorflow:step = 8312, loss = 44.25933 (1.011 sec)
# INFO:tensorflow:global_step/sec: 97.4357
# INFO:tensorflow:step = 8412, loss = 50.48991 (1.026 sec)
# INFO:tensorflow:global_step/sec: 95.1432
# INFO:tensorflow:step = 8512, loss = 48.472145 (1.050 sec)
# INFO:tensorflow:Saving checkpoints for 8593 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 49.85035.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:10:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-8593
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:10:45
# INFO:tensorflow:Saving dict for global step 8593: average_loss = 0.09214112, global_step = 8593, loss = 47.148075
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-8593
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081845'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-8593
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 8594 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 8594, loss = 47.363472
# INFO:tensorflow:global_step/sec: 89.8045
# INFO:tensorflow:step = 8694, loss = 50.19419 (1.120 sec)
# INFO:tensorflow:global_step/sec: 95.9812
# INFO:tensorflow:step = 8794, loss = 46.11349 (1.040 sec)
# INFO:tensorflow:global_step/sec: 95.4349
# INFO:tensorflow:step = 8894, loss = 42.89343 (1.048 sec)
# INFO:tensorflow:global_step/sec: 92.8256
# INFO:tensorflow:step = 8994, loss = 44.57312 (1.078 sec)
# INFO:tensorflow:global_step/sec: 99.0569
# INFO:tensorflow:step = 9094, loss = 46.49058 (1.008 sec)
# INFO:tensorflow:global_step/sec: 99.1117
# INFO:tensorflow:step = 9194, loss = 48.665848 (1.011 sec)
# INFO:tensorflow:global_step/sec: 97.1561
# INFO:tensorflow:step = 9294, loss = 47.992287 (1.027 sec)
# INFO:tensorflow:global_step/sec: 96.1745
# INFO:tensorflow:step = 9394, loss = 51.460587 (1.040 sec)
# INFO:tensorflow:Saving checkpoints for 9464 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 46.296707.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:10:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-9464
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:11:06
# INFO:tensorflow:Saving dict for global step 9464: average_loss = 0.09212571, global_step = 9464, loss = 47.140186
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-9464
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081866'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-9464
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9465 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:step = 9465, loss = 43.727425
# INFO:tensorflow:global_step/sec: 88.7634
# INFO:tensorflow:step = 9565, loss = 48.46647 (1.133 sec)
# INFO:tensorflow:global_step/sec: 97.5132
# INFO:tensorflow:step = 9665, loss = 48.493423 (1.023 sec)
# INFO:tensorflow:global_step/sec: 95.5508
# INFO:tensorflow:step = 9765, loss = 42.53531 (1.050 sec)
# INFO:tensorflow:global_step/sec: 94.952
# INFO:tensorflow:step = 9865, loss = 43.144867 (1.053 sec)
# INFO:tensorflow:global_step/sec: 91.4213
# INFO:tensorflow:step = 9965, loss = 43.759495 (1.090 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into tfl_trained_120419_1600/model.ckpt.
# INFO:tensorflow:Loss for final step: 51.785507.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-12-15:11:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-12-15:11:24
# INFO:tensorflow:Saving dict for global step 10000: average_loss = 0.09252347, global_step = 10000, loss = 47.34372
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'precipIntensity': <tf.Tensor 'Placeholder_5:0' shape=(?,) dtype=float32>, 'temperature': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'weekend': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=string>, 'badWeather': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=string>, 'dayofweek': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=string>, 'hour': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from tfl_trained_120419_1600/model.ckpt-10000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"tfl_trained_120419_1600/export/exporter/temp-b'1555081884'/saved_model.pb"

# %%
from tensorflow.contrib.learn.python.learn.utils import saved_model_export_utils
from tensorflow.contrib.learn.python.learn import learn_runner

PATTERN = ""  # process only one of the shards, for testing purposes

def train_and_evaluate(output_dir):
    wide, deep = get_wide_deep()
    estimator = tf.estimator.DNNLinearCombinedRegressor(
                         model_dir=output_dir,
                         linear_feature_columns=wide,
                         dnn_feature_columns=deep,
                         dnn_hidden_units=[64, 32])#,
                         #config = run_config)
    train_spec=tf.estimator.TrainSpec(
                         input_fn=read_dataset('train', PATTERN),
                         max_steps=10000)
    exporter = tf.estimator.LatestExporter('exporter',serving_input_fn)
    eval_spec=tf.estimator.EvalSpec(
                         input_fn=read_dataset('eval', PATTERN),
                         steps=None,
                         start_delay_secs = 1, # start evaluating after N seconds
                         throttle_secs = 10,  # evaluate every N seconds
                         exporters=exporter)
    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
    
shutil.rmtree('tfl_trained_100419', ignore_errors=True) # start fresh each time
train_and_evaluate('tfl_trained_100419')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c51a2cdf0e68> in <module>()
#      25
#      26 shutil.rmtree('tfl_trained_100419', ignore_errors=True) # start fresh each time
# ---> 27 train_and_evaluate('tfl_trained_100419')
#
# <ipython-input-18-c51a2cdf0e68> in train_and_evaluate(output_dir)
#       9                          model_dir=output_dir,
#      10                          linear_feature_columns=features,
# ---> 11                          dnn_feature_columns=deep,
#      12                          dnn_hidden_units=[64, 32])#,
#      13                          #config = run_config)
#
# NameError: name 'deep' is not defined

# %%
# !ls -lrt tfl_trained
# Out:
# ls: cannot access 'tfl_trained': No such file or directory

# %%
# to stop TensorBoard
from google.datalab.ml import TensorBoard
for pid in TensorBoard.list()['pid']:
    TensorBoard().stop(pid)
    print('Stopped TensorBoard with pid {}'.format(pid))
# Out:
# Stopped TensorBoard with pid 6085

# %%
from google.datalab.ml import TensorBoard
TensorBoard().start('./tfl_trained_100419')
TensorBoard().list()
# Out:
# <p>TensorBoard was started successfully with pid 48821. Click <a href="/_proxy/51861/" target="_blank">here</a> to access it.</p>
#                  logdir    pid   port
# 0  ./tfl_trained_100419  48821  51861
